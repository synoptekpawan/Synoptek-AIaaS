# %%
# Installing libraries
# !pip install datasets evaluate transformers[sentencepiece]
# !pip install faiss-gpu
# !pip install datasets
# !pip install sentence-transformers
##!nvidia-smi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.8.0-py3-none-any.whl (452 kB)
#      |████████████████████████████████| 452 kB 30.9 MB/s
# Collecting evaluate
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 13.6 MB/s
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 68.1 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py38-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 80.4 MB/s
# Collecting huggingface-hub<1.0.0,>=0.2.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 78.2 MB/s
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      |████████████████████████████████| 213 kB 66.7 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (21.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 54.7 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 59.9 MB/s
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 59.2 MB/s
# Requirement already satisfied: protobuf<=3.20.2 in /usr/local/lib/python3.8/dist-packages (from transformers[sentencepiece]) (3.19.6)
# Installing collected packages: urllib3, xxhash, tokenizers, responses, multiprocess, huggingface-hub, transformers, sentencepiece, datasets, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.8.0 evaluate-0.4.0 huggingface-hub-0.11.1 multiprocess-0.70.14 responses-0.18.0 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.25.1 urllib3-1.25.11 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      |████████████████████████████████| 85.5 MB 74 kB/s
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.8/dist-packages (2.8.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.8/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.8/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (2022.11.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.11.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.8/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (6.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from datasets) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.8/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.8/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (6.0.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.0 MB/s
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (4.25.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (0.14.0+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (1.7.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (3.7)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers) (0.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.25.11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=42cf1b53416c45c098f685a6fafb2365eb3b50571829713c808213f24ddea899
#   Stored in directory: /root/.cache/pip/wheels/5e/6f/8c/d88aec621f3f542d26fac0342bef5e693335d125f4e54aeffe
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.2

# %%
# Connecting to g drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import time

start = time.time()

# %%
# Importing library
import pandas as pd
import re
import time
from tqdm import tqdm
import seaborn as sns
import numpy as np
from textblob import TextBlob
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('distilbert-base-nli-stsb-mean-tokens')
# Out:
# Downloading:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.01k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/555 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/265M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/505 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# Reading April-June csv
a = pd.read_csv(r'/content/gdrive/MyDrive/iBas-Data/iBAS-Apr-June-2022-Ticket Search Results.csv')
print(a.shape)
# Reading Jan-March csv
b = pd.read_csv(r'/content/gdrive/MyDrive/iBas-Data/iBAS-Jan-Mar-2022-Ticket Search Results.csv')
print(b.shape)
# Reading July-August csv
c = pd.read_csv(r'/content/gdrive/MyDrive/iBas-Data/iBAS-July-Aug-2022-Ticket Search Results.csv')
print(c.shape)
# Out:
# (4934, 15)
# (4475, 15)
# (3146, 15)

# %%
df1 = a.append(b)
df = df1.append(c)
print(df.shape)
# Out:
# (12555, 15)

# %%
print(df.shape)
# Removing duplicate ticket number and description
df.drop_duplicates(subset=['Ticket Number','Description'],inplace=True)
print(df.shape)
# Out:
# (12555, 15)
# (12555, 15)

# %%
# Merging data of all 3 data frames
df.to_csv('Merged_Data.csv',index= False)

# %%
df.rename(columns = {'Title':'Ticket_Title'}, inplace = True)
df.rename(columns = {'Ticket Number':'Ticket_Number'}, inplace = True)
df.rename(columns = {'Issue Type':'Issue_Type'}, inplace = True)
df.rename(columns = {'Sub-Issue Type':'Sub_Issue_Type'}, inplace = True)
df.rename(columns = {'Create Date/Time':'Create_Date/Time'}, inplace = True)
df.rename(columns = {'Complete Date/Time':'Complete_Date/Time'}, inplace = True)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import word_tokenize

# Function to identify REPLY emails
def replacing1(text) :
  count = 0
  removed = []
  tokens = word_tokenize(text)
  for i in range(len(tokens)):
      if tokens[i] == 'RE' or tokens[i] == 're' or tokens[i] == 'Re':
        #print('ok')
        removed.append('1')
      else :
        continue
  return " ".join(removed)

df['Ticket_Title_1'] = df['Ticket_Title'].apply(lambda x: replacing1(x))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#df = df.head(2)

# %%
names = []
# Extracting name from email id
def extract_name_email(text) :
  e = []
  text = str(text)
  tokens = word_tokenize(text)
  lst = re.findall('\S+@\S+', text)   
  regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
  for i in lst :
    if(re.fullmatch(regex, i)):
      x = i.split("@")
      names.extend(x)
      #print('x',x)
      y = i.split(".")
      names.extend(y)
      #print('y',y)
      if len(y) != 0 :
        for l in y :
          z = l.split("@")
          names.extend(z)
          #print('z',z)
    else :
      continue
  n = list(set(names))
  #print('n',n)
  for i in range(len(tokens)) :
    if tokens[i] in n :
      continue
    else :
      e.append(tokens[i])
  #print(e)
  return " ".join(e)

# %%
# Converting text to lower case
def convert_to_lower(text):
    text = str(text)
    return text.lower()

def remove_voice_questions(text) :
  text = str(text)
  tokens = word_tokenize(text)
  t = []
  c = ['nt','know','me']
  for i in range(len(tokens)) :
    t.append(tokens[i])

  for j in range(len(tokens)) :
    if t[0] == 'your' :
      #if (t[j] == 'impacted') and ((t[j+1] == 'others') or (t[j+1] == 'company') or (t[j+1] == 'nt') or (t[j]=='only' and t[j+1]=='me')) :
      #break 
      index = t.index('impacted')
      t = t[index+2:]
      break
    else :
      continue
  if t is None :
    t = []
    t.append('Empty')

# Customize email -- removing subject, regards
def tok(text):  
    text = str(text)
    tokens = word_tokenize(text)
    #print(tokens)
    c = []
    removed = []
    for i in range(len(tokens)):
        #print(tokens[i])
        if (i+2 < len(tokens)) or (i < len(tokens)) or (i+1 < len(tokens)) :
          #print("(i+2 < len(tokens)) or (i < len(tokens)) or (i+1 < len(tokens))",i+2,i,i+1,tokens[i])
          try :
            if (tokens[i] == 'from' and tokens[i+1] == ':') or (tokens[i]==':' and tokens[i-1] == 'from') or (tokens[i] == 'from' and tokens[i+1] == 'name') :
              continue
            elif (tokens[i] == 'email' and tokens[i+1] == 'body') or (tokens[i-1] == 'email' and tokens[i] == 'body'):
              continue
            elif ((tokens[i] == 'hi' or tokens[i] == 'hello') and (tokens[i+1] == 'team')) or (tokens[i] == 'ty'):
              continue
            elif (tokens[i] == 'good'  and tokens[i+1] == 'morning') or (tokens[i-1] == 'good'  and tokens[i] == 'morning') :
              continue
            elif (tokens[i] == 'hello'  and tokens[i+1] == ',') or (tokens[i] == 'hey') or (tokens[i] == 'name'  and tokens[i+1] == ':') :
              continue
            elif ((tokens[i-1] == 'hi' or tokens[i-1] == 'hello') and (tokens[i] == 'team')) :
              continue
            elif (tokens[i-1] == 'get' and tokens[i] == 'outlook' and tokens[i+1] == 'for' ) :
              continue
            elif (tokens[i] == 'to' and tokens[i+1] == ':') or (tokens[i] == 'cc'):
              continue
            elif (tokens[i] =='cid') :
              break
            elif (tokens[i] == 'regards' or tokens[i] == 'regard' or tokens[i] == 'thanks' or tokens[i] == 'thank') and (tokens[i+1] != 'for') or (tokens[i] == 'get' and tokens[i+1] == 'outlook' and tokens[i+2] == 'for') or (tokens[i] == 'regards' and tokens[i+1] == ','):
              break
            #elif (tokens[i] == 'get' and tokens[i+1] == 'outlook' and tokens[i+2] == 'for') or (tokens[i] == 'regards' and tokens[i+1] == ','):
             # break
            else :
              c.append(tokens[i])
          except :
            continue
        elif (i+2 > len(tokens)) or (i == len(tokens)) or (i+1 > len(tokens)) :
          c.append(tokens[i])
    
    if ('<' in c) and ('>' in c) :
      l = c.index('<')
      j = c.index('>')
      t = c[:l]
      u = c[j+1:]
      c = t + u
      ##print('if')
        
    return " ".join(c)

def remove_urls(text):
    # Use a regular expression to search for URLs
    url_pattern = r'https?://\S+'
    return re.sub(url_pattern, '', text)

def re_num_tt(text) :
  number_pattern = r'[~^0-9]'
  return re.sub(number_pattern, '', text)


# Merging code of Software names
def remove_numbers(text):
    text = str(text)
    number_pattern = r'[~^0-9]'
    tokens = word_tokenize(text)
    #print(tokens)
    #print("len(tokens)",len(tokens))
    t = []
    for i in range(len(tokens)):
      #print(i)
      try :
        if (i == len(tokens)-1) :
          #print("(i == len(tokens)-1)",i)
          t.append(tokens[i])
        elif (tokens[i] == 'office' or  tokens[i] =='office365') and (tokens[i+1] == '365') :
            #print('office365')
            t.append('office365')
        elif (tokens[i] == 'bau') and (tokens[i+1] =='360') :
            t.append('bau360')
        elif (tokens[i] == 'forti' and tokens[i+1] == 'client') :
            #print('forticlient')
            t.append('forticlient')
        elif (tokens[i]=='non') and (tokens[i+1] == 'prod') :
            t.append('nonprod')
        elif (tokens[i] == 'as' and tokens[i+1] == '400') or (tokens[i] == 'as400') :
            #print('as400')
            t.append('as400')    
        elif (tokens[i]== 'e3') or (tokens[i]== 'e3') or (tokens[i]== 'ec2') or (tokens[i]== 'develop03') or (tokens[i]== 'ie5') or (tokens[i]== 'ie10') or (tokens[i]== 'as400'):
            t.append(tokens[i])
        elif (tokens[i]== 'case') or (tokens[i+1]== '360') or (tokens[i]== 'case360') :
            #print('case360')
            t.append('case360')
        elif (tokens[i]== 'db' or tokens[i]== 'data') and (tokens[i+1]== 'base'):
            t.append('database')
        elif (tokens[i]=='non') and (tokens[i]=='prod') :
            t.append('nonprod')
        elif (tokens[i]== 'ms') :
            t.append('microsoft')
        elif (tokens[i]== 'screen') or (tokens[i]== 'shot') :
            t.append('screenshot')
        elif (tokens[i] == 'do') and (tokens[i] == 'nt') :
            t.append('do')
            t.apppend('not')
        elif (tokens[i] == 'pfa') :
            #print('pfa')
            t.append('please')
            t.append('find')
            t.append('attachment')
        elif (tokens[i] == 'eod') :
            #print('eod')
            t.append('end')
            t.append('of')
            t.append('day')
        elif (tokens[i] == 'pw') :
            #print('eod')
            t.append('password')
        elif (tokens[i]== 'five9') or (tokens[i]=='five') or (tokens[i+1]=='9') :
            t.append('five9')
        elif (tokens[i]=='vpn') :
            t.append('vpn')
        elif (tokens[i]== 'app') :
            t.append('application')
        elif (tokens[i]=='vm') :
            t.append('virtual')
            t.append('machine')
        elif (tokens[i]=='appo6') :
            t.append('appo6')
        elif (tokens[i]== 'PW' or tokens[i]=='pw' or tokens[i]=='password') :
            t.append('password')
        elif (tokens[i] == 'tciket') :
            t.append('ticket')
        elif (tokens[i] == 'ca') and (tokens[i] == 'nt') :
            t.append('cannot')
        ## else :
            #without_number = re.sub(pattern=number_pattern, repl="", string=tokens[i])
            #t.append(str(without_number))
        elif tokens[i].isnumeric() and (t[-1] == 'appo6' or t[-1] == 'office365' or t[-1] == 'five9' or t[-1] == 'case360' or t[-1] == 'as400' or t[-1] == 'ec2' or t[-1] == 'bau360' or t[-1] == 'e3' or t[-1] == 'ie5' or t[-1] == 'ie10') :
          continue
        elif (tokens[i] == 'from' and tokens[i+1] == 'name') or (tokens[i-1] == 'from' and tokens[i] == 'name'):
          continue
        else :
          t.append(tokens[i])
          #print("t.append(tokens[i])",tokens[i])
      except :
        continue
    #print(t)
    return " ".join(t)

# Removing function
import string
def remove_punctuation(text):
    # Make a translation table to remove all punctuation symbols
    translator = text.maketrans('', '', string.punctuation)
    # Use the translation table to remove all punctuation symbols from the text
    return text.translate(translator)

# %%
# Replacing office 365 to office365
df['Description_lower'] = df['Description'].apply(lambda x: convert_to_lower(x))   
df['Description_email'] = df['Description_lower'].apply(lambda x: extract_name_email(x))
df['Description_url'] = df['Description_email'].apply(lambda x: remove_urls(x)) 
df['Description_tok'] = df['Description_url'].apply(lambda x: tok(x))
df['Description_punc'] = df['Description_tok'].apply(lambda x: remove_punctuation(x))
df['Description_digits'] = df['Description_punc'].apply(lambda x: remove_numbers(x)) 
##df['Description_1'] = df['Description_digits'].apply(lambda x: remove_voice_questions(x))

# %%
df['Ticket_Title'] = df['Ticket_Title'].apply(lambda x: convert_to_lower(x))   
df['Ticket_Title'] = df['Ticket_Title'].apply(lambda x: tok(x))
df['Ticket_Title'] = df['Ticket_Title'].apply(lambda x: remove_numbers(x)) 
df['Ticket_Title'] = df['Ticket_Title'].apply(lambda x: re_num_tt(x))

# %%
df['Description_email'][1]
# Out:
# 1    from : @ from name : to : @ cc : @ email body ...
# 1    backup job exceeded running time of 24 hrs - p...
# 1    user is requesting set up for forticlient vpn ...
# Name: Description_email, dtype: object

# %%
#df['Description_tok'][1]

# %%
#df['Description_digits'][1]

# %%
print(df.shape)
df.drop_duplicates(subset='Ticket_Number', keep="first")
print(df.shape)
# Out:
# (12555, 22)
# (12555, 22)

# %%
print(df.shape)
df =df[df['Ticket_Title_1'] == '']
print(df.shape)
# Out:
# (12555, 22)
# (11122, 22)

# %%
# Merging ticket title and description
df['Description_re_concate'] = df['Description_digits'] + ' ' + df['Ticket_Title']
# Out:
# <ipython-input-21-369a5e7b79e2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Description_re_concate'] = df['Description_digits'] + ' ' + df['Ticket_Title']

# %%
df.to_csv('Text_Processing.csv',index= False)

# %%
# Pre trained Sentence Transformers
from transformers import AutoTokenizer, AutoModel

model_ckpt = "sentence-transformers/multi-qa-mpnet-base-dot-v1"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)
model = AutoModel.from_pretrained(model_ckpt)
# Out:
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
import torch

device = torch.device("cuda")
model.to(device)
# Out:
# MPNetModel(
#   (embeddings): MPNetEmbeddings(
#     (word_embeddings): Embedding(30527, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): MPNetEncoder(
#     (layer): ModuleList(
#       (0): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): MPNetLayer(
#         (attention): MPNetAttention(
#           (attn): MPNetSelfAttention(
#             (q): Linear(in_features=768, out_features=768, bias=True)
#             (k): Linear(in_features=768, out_features=768, bias=True)
#             (v): Linear(in_features=768, out_features=768, bias=True)
#             (o): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (intermediate): MPNetIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): MPNetOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (relative_attention_bias): Embedding(32, 12)
#   )
#   (pooler): MPNetPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
def cls_pooling(model_output):
    return model_output.last_hidden_state[:, 0]

def get_embeddings(text_list):
  encoded_input = tokenizer(
  text_list, padding=True, truncation=True, return_tensors="pt")
  encoded_input = {k: v.to(device) for k, v in encoded_input.items()}
  model_output = model(**encoded_input)
  return cls_pooling(model_output)

# %%
from datasets import Dataset

comments_dataset = Dataset.from_pandas(df)
comments_dataset
# Out:
# Dataset({
#     features: ['Classification', 'Ticket_Number', 'Ticket_Title', 'Description', 'Account', 'Queue', 'Resources', 'Status', 'Priority', 'Created', 'Due', 'Impact', 'Issue_Type', 'Sub_Issue_Type', 'Resolution', 'Ticket_Title_1', 'Description_lower', 'Description_email', 'Description_url', 'Description_tok', 'Description_punc', 'Description_digits', 'Description_re_concate', '__index_level_0__'],
#     num_rows: 11122
# })

# %%
embedding = get_embeddings(comments_dataset['Description_re_concate'][0])
embedding.shape
# Out:
# torch.Size([1, 768])

# %%
embeddings_dataset = comments_dataset.map(
    lambda x: {"embeddings": get_embeddings(x["Description_re_concate"]).detach().cpu().numpy()[0]}
)
# Out:
#   0%|          | 0/11122 [00:00<?, ?ex/s]

# %%
embeddings_dataset.add_faiss_index(column="embeddings")
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# Dataset({
#     features: ['Classification', 'Ticket_Number', 'Ticket_Title', 'Description', 'Account', 'Queue', 'Resources', 'Status', 'Priority', 'Created', 'Due', 'Impact', 'Issue_Type', 'Sub_Issue_Type', 'Resolution', 'Ticket_Title_1', 'Description_lower', 'Description_email', 'Description_url', 'Description_tok', 'Description_punc', 'Description_digits', 'Description_re_concate', '__index_level_0__', 'embeddings'],
#     num_rows: 11122
# })

# %%
embeddings_dataset
# Out:
# Dataset({
#     features: ['Classification', 'Ticket_Number', 'Ticket_Title', 'Description', 'Account', 'Queue', 'Resources', 'Status', 'Priority', 'Created', 'Due', 'Impact', 'Issue_Type', 'Sub_Issue_Type', 'Resolution', 'Ticket_Title_1', 'Description_lower', 'Description_email', 'Description_url', 'Description_tok', 'Description_punc', 'Description_digits', 'Description_re_concate', '__index_level_0__', 'embeddings'],
#     num_rows: 11122
# })

# %%
#question = "documents not opening in case360"
question = "teams login error"
question_embedding = get_embeddings([question]).cpu().detach().numpy()
question_embedding.shape
# Out:
# (1, 768)

# %%
import pickle
# Save the text embeddings to a file using pickle
with open("text_embeddings.pkl", "wb") as f:
    pickle.dump(embeddings_dataset, f)

# %%
scores, samples = embeddings_dataset.get_nearest_examples(
    "embeddings", question_embedding, k=20
)

# %%
import pandas as pd

samples_df = pd.DataFrame.from_dict(samples)
samples_df["scores"] = scores

# %%
samples_df.columns
# Out:
# Index(['Classification', 'Ticket_Number', 'Ticket_Title', 'Description',
#        'Account', 'Queue', 'Resources', 'Status', 'Priority', 'Created', 'Due',
#        'Impact', 'Issue_Type', 'Sub_Issue_Type', 'Resolution',
#        'Ticket_Title_1', 'Description_lower', 'Description_email',
#        'Description_url', 'Description_tok', 'Description_punc',
#        'Description_digits', 'Description_re_concate', '__index_level_0__',
#        'embeddings', 'scores'],
#       dtype='object')

# %%
samples_df.head(5)
# Out:
#   Classification   Ticket_Number                               Ticket_Title  \
# 0  CDS-Northwest  T20220822.0393   unable to log in to sharepoint and teams
# 1  CDS-Northwest  T20220831.0605                 unable to sign in to teams
# 2  CDS-Northwest  T20220302.0188                                teams error
# 3  CDS-Northwest  T20220125.0391  not able to login on microsoft teams - #
# 4  CDS-Northwest  T20220303.0229             can not access microsoft teams
#
#                                          Description           Account  \
# 0  Unable to log in to Sharepoint and Teams\n\nCB...  iBAS, Inc (CHCS)
# 1                     She said password has expired.  iBAS, Inc (CHCS)
# 2  FROM: Manish-Kumar.Verma@chcs-services.com\nFR...  iBAS, Inc (CHCS)
# 3  FROM: servicedeskbpo.global@capgemini.com\nFRO...  iBAS, Inc (CHCS)
# 4  FROM: kathleen.brown@chcs-services.com\nFROM N...  iBAS, Inc (CHCS)
#
#                         Queue                 Resources    Status  \
# 0  Global Shared Service Desk   GUPTA, MUKESH (primary)  Complete
# 1  Global Shared Service Desk  YBARSABAL, RAY (primary)  Complete
# 2              Merged Tickets   LEDESMA, TONY (primary)  Complete
# 3  Global Shared Service Desk  SONI, JITENDRA (primary)  Complete
# 4               CDS-Northwest    CURRIE, SEAN (primary)  Complete
#
#           Priority          Created  ...  \
# 0    P3 - Moderate  8/22/2022 19:26  ...
# 1    P3 - Moderate  8/31/2022 20:40  ...
# 2        Scheduled   3/2/2022 18:26  ...
# 3    P2 - Impaired  1/25/2022 21:26  ...
# 4  P4 - Functional   3/3/2022 18:36  ...
#
#                                    Description_lower  \
# 0  unable to log in to sharepoint and teams\n\ncb...
# 1                     she said password has expired.
# 2  from: manish-kumar.verma@chcs-services.com\nfr...
# 3  from: servicedeskbpo.global@capgemini.com\nfro...
# 4  from: kathleen.brown@chcs-services.com\nfrom n...
#
#                                    Description_email  \
# 0  unable to log to sharepoint and teams cb : 208...
# 1                    she said password has expired .
# 2  from : @ from name : manish to : @ cc : @ ; @ ...
# 3  from : @ from name : bsv it , desk to : @ cc :...
# 4  from : @ from name : to : @ cc : email body : ...
#
#                                      Description_url  \
# 0  unable to log to sharepoint and teams cb : 208...
# 1                    she said password has expired .
# 2  from : @ from name : manish to : @ cc : @ ; @ ...
# 3  from : @ from name : bsv it , desk to : @ cc :...
# 4  from : @ from name : to : @ cc : email body : ...
#
#                                      Description_tok  \
# 0  unable to log to sharepoint and teams cb : 208...
# 1                    she said password has expired .
# 2  @ : manish : @ : @ ; @ ; @ : , am getting belo...
# 3  @ : bsv it , desk : @ : @ ; @ : , below users ...
# 4  @ : : @ : : , am receiving the below error mes...
#
#                                     Description_punc  \
# 0  unable to log to sharepoint and teams cb  2084...
# 1                     she said password has expired
# 2    manish           am getting below error whil...
# 3    bsv it  desk         below users are not abl...
# 4         am receiving the below error message wh...
#
#                                   Description_digits  \
# 0  unable to log to sharepoint and teams cb 20840...
# 1                      she said password has expired
# 2  manish am getting below error while login into...
# 3  bsv it desk below users are not able to login ...
# 4  am receiving the below error message when try ...
#
#                               Description_re_concate __index_level_0__  \
# 0  unable to log to sharepoint and teams cb 20840...              2669
# 1  she said password has expired unable to sign i...              3138
# 2  manish am getting below error while login into...              1974
# 3  bsv it desk below users are not able to login ...               166
# 4  am receiving the below error message when try ...              2078
#
#                                           embeddings     scores
# 0  [-0.20379874110221863, -0.14271019399166107, -...  14.659274
# 1  [-0.06729351729154587, -0.20569178462028503, -...  15.462677
# 2  [-0.21326568722724915, -0.2221154123544693, -0...  15.561868
# 3  [0.27587559819221497, -0.7293131947517395, -0....  16.956728
# 4  [-0.4583558440208435, -0.2991095185279846, -0....  17.276005
#
# [5 rows x 26 columns]

# %%
from numpy.linalg import norm
import numpy as np
cos = []
for i in samples_df['embeddings'] :
  cosine = np.dot(question_embedding,i)/(norm(question_embedding)*norm(i))
  cos.append(cosine)

samples_df['Cosine_Simlarity'] = cos

# %%
samples_df
# Out:
#    Classification   Ticket_Number  \
# 0   CDS-Northwest  T20220822.0393
# 2   CDS-Northwest  T20220302.0188
# 1   CDS-Northwest  T20220831.0605
# 3   CDS-Northwest  T20220125.0391
# 5   CDS-Northwest  T20220325.1419
# 4   CDS-Northwest  T20220303.0229
# 6   CDS-Northwest  T20220124.0470
# 7   CDS-Northwest  T20220308.1720
# 8   CDS-Northwest  T20220422.0611
# 9   CDS-Northwest  T20220520.0555
# 11  CDS-Northwest  T20220422.0566
# 13  CDS-Northwest  T20220805.0677
# 12  CDS-Northwest  T20220627.0187
# 10  CDS-Northwest  T20220223.0372
# 16  CDS-Northwest  T20220516.0649
# 19  CDS-Northwest  T20220516.1576
# 14  CDS-Northwest  T20220314.0560
# 18  CDS-Northwest  T20220808.0474
# 15  CDS-Northwest  T20220405.0599
# 17  CDS-Northwest  T20220606.1899
#
#                                          Ticket_Title  \
# 0            unable to log in to sharepoint and teams
# 2                                         teams error
# 1                          unable to sign in to teams
# 3           not able to login on microsoft teams - #
# 5                          not able to login in teams
# 4                      can not access microsoft teams
# 6                not able to login on microsoft teams
# 7                                         teams issue
# 8                             teams application issue
# 9                                         teams issue
# 11                                        teams issue
# 13                             unable to access teams
# 12        acccess to microsoft teams on mobile device
# 10                     unable to login in keeper team
# 16  teams application installation required on use...
# 19                           required microsoft teams
# 14                      microsoft teams not launching
# 18                               teams is not working
# 15                    need to install microsoft teams
# 17                                  wifi connection .
#
#                                           Description           Account  \
# 0   Unable to log in to Sharepoint and Teams\n\nCB...  iBAS, Inc (CHCS)
# 2   FROM: Manish-Kumar.Verma@chcs-services.com\nFR...  iBAS, Inc (CHCS)
# 1                      She said password has expired.  iBAS, Inc (CHCS)
# 3   FROM: servicedeskbpo.global@capgemini.com\nFRO...  iBAS, Inc (CHCS)
# 5                                                None  iBAS, Inc (CHCS)
# 4   FROM: kathleen.brown@chcs-services.com\nFROM N...  iBAS, Inc (CHCS)
# 6   FROM: amit.kashyap@chcs-services.com\nFROM NAM...  iBAS, Inc (CHCS)
# 7                         Teams Issue\nCB:-8505541324  iBAS, Inc (CHCS)
# 8             Team application issue\nCB:520.443.1666  iBAS, Inc (CHCS)
# 9   Kate called to advise she is having some probl...  iBAS, Inc (CHCS)
# 11  CB: 520-443-1666\n\nUser was having an issue w...  iBAS, Inc (CHCS)
# 13  When trying to access Teams Natasha gets a pro...  iBAS, Inc (CHCS)
# 12  User is having issues logging into to  teams o...  iBAS, Inc (CHCS)
# 10  FROM: Manmeet.Singh@chcs-services.com\nFROM NA...  iBAS, Inc (CHCS)
# 16  Teams application installation required on Use...  iBAS, Inc (CHCS)
# 19  Required MS Teams.\nHostname: DESKTOP-ET22M6N\...  iBAS, Inc (CHCS)
# 14  FROM: Avery.Stearns@chcs-services.com\nFROM NA...  iBAS, Inc (CHCS)
# 18  FROM: samridhi.badola@chcs-services.com\nFROM ...  iBAS, Inc (CHCS)
# 15                           Need to install MS Teams  iBAS, Inc (CHCS)
# 17  Manoj connected on Teams and informed us that ...  iBAS, Inc (CHCS)
#
#                          Queue  \
# 0   Global Shared Service Desk
# 2               Merged Tickets
# 1   Global Shared Service Desk
# 3   Global Shared Service Desk
# 5   Global Shared Service Desk
# 4                CDS-Northwest
# 6   Global Shared Service Desk
# 7   Global Shared Service Desk
# 8   Global Shared Service Desk
# 9   Global Shared Service Desk
# 11  Global Shared Service Desk
# 13        Business Development
# 12  Global Shared Service Desk
# 10              Merged Tickets
# 16  Global Shared Service Desk
# 19  Global Shared Service Desk
# 14               CDS-Northwest
# 18  Global Shared Service Desk
# 15  Global Shared Service Desk
# 17  Global Shared Service Desk
#
#                                             Resources    Status  \
# 0                             GUPTA, MUKESH (primary)  Complete
# 2                             LEDESMA, TONY (primary)  Complete
# 1                            YBARSABAL, RAY (primary)  Complete
# 3                            SONI, JITENDRA (primary)  Complete
# 5            PARMAR, NIKUNJ (primary) | PATODI, ANKIT  Complete
# 4                              CURRIE, SEAN (primary)  Complete
# 6                            YBARSABAL, RAY (primary)  Complete
# 7                             PATODI, ANKIT (primary)  Complete
# 8                      ODIYAR, CHANDRAKIRAN (primary)  Complete
# 9                             WILLS, ANDREW (primary)  Complete
# 11                       EACHAMBADI, NAUNIT (primary)  Complete
# 13  PETERSON, BRADLEY (primary) | BOONE, JAKE | CH...  Complete
# 12                             AUGUSTE, RUU (primary)  Complete
# 10                            LEDESMA, TONY (primary)  Complete
# 16                       BHOGAYATA, KAMLESH (primary)  Complete
# 19                     ODIYAR, CHANDRAKIRAN (primary)  Complete
# 14                              CHUNG, PAUL (primary)  Complete
# 18                       BHOGAYATA, KAMLESH (primary)  Complete
# 15                      CHOUDHARY, SHASHANK (primary)  Complete
# 17  PATEL, PARTH (primary) | BHOGAYATA, KAMLESH | ...  Complete
#
#            Priority          Created  ...  \
# 0     P3 - Moderate  8/22/2022 19:26  ...
# 2         Scheduled   3/2/2022 18:26  ...
# 1     P3 - Moderate  8/31/2022 20:40  ...
# 3     P2 - Impaired  1/25/2022 21:26  ...
# 5     P3 - Moderate   3/26/2022 4:23  ...
# 4   P4 - Functional   3/3/2022 18:36  ...
# 6     P3 - Moderate  1/24/2022 21:47  ...
# 7     P3 - Moderate    3/9/2022 1:08  ...
# 8   P4 - Functional  4/22/2022 21:16  ...
# 9     P3 - Moderate  5/20/2022 19:39  ...
# 11    P3 - Moderate  4/22/2022 20:50  ...
# 13        Scheduled   8/5/2022 21:39  ...
# 12        Scheduled  6/27/2022 16:13  ...
# 10        Scheduled  2/23/2022 19:07  ...
# 16    P3 - Moderate  5/16/2022 20:30  ...
# 19  P4 - Functional   5/17/2022 2:08  ...
# 14        Scheduled  3/14/2022 19:22  ...
# 18    P3 - Moderate   8/8/2022 15:19  ...
# 15    P3 - Moderate   4/5/2022 20:19  ...
# 17        Scheduled   6/7/2022 10:47  ...
#
#                                       Description_url  \
# 0   unable to log to sharepoint and teams cb : 208...
# 2   from : @ from name : manish to : @ cc : @ ; @ ...
# 1                     she said password has expired .
# 3   from : @ from name : bsv it , desk to : @ cc :...
# 5                                                 nan
# 4   from : @ from name : to : @ cc : email body : ...
# 6   from : @ from name : to : @ ; @ ; dmodi @ cc :...
# 7                        teams issue cb : -8505541324
# 8              team application issue cb:520.443.1666
# 9   called to advise she is having some problems s...
# 11  cb : 520-443-1666 user was having an issue wit...
# 13  when trying to access teams natasha gets promp...
# 12  user is having issues logging into to teams on...
# 10  from : @ from name : to : @ ; @ cc : email bod...
# 16  teams application installation required on use...
# 19  required ms teams . hostname : desktop-et22m6n...
# 14  from : @ from name : to : @ cc : @ email body ...
# 18  from : @ from name : to : @ cc : @ email body ...
# 15                           need to install ms teams
# 17  connected on teams and informed us that the co...
#
#                                       Description_tok  \
# 0   unable to log to sharepoint and teams cb : 208...
# 2   @ : manish : @ : @ ; @ ; @ : , am getting belo...
# 1                     she said password has expired .
# 3   @ : bsv it , desk : @ : @ ; @ : , below users ...
# 5                                                 nan
# 4   @ : : @ : : , am receiving the below error mes...
# 6   @ : : @ ; @ ; dmodi @ : @ ; @ ; @ ; @ ; hemend...
# 7                        teams issue cb : -8505541324
# 8              team application issue cb:520.443.1666
# 9   called to advise she is having some problems s...
# 11  cb : 520-443-1666 user was having an issue wit...
# 13  when trying to access teams natasha gets promp...
# 12  user is having issues logging into to teams on...
# 10  @ : : @ ; @ : : , i am unable to login keeper ...
# 16  teams application installation required on use...
# 19  required ms teams . hostname : desktop-et22m6n...
# 14  @ : : @ : @ : hi , my microsoft teams is not o...
# 18  @ : : @ : @ : hi , my teams application is not...
# 15                           need to install ms teams
# 17  connected on teams and informed us that the co...
#
#                                      Description_punc  \
# 0   unable to log to sharepoint and teams cb  2084...
# 2     manish           am getting below error whil...
# 1                      she said password has expired
# 3     bsv it  desk         below users are not abl...
# 5                                                 nan
# 4          am receiving the below error message wh...
# 6          dmodi           hemendradeopa    below ...
# 7                          teams issue cb  8505541324
# 8                 team application issue cb5204431666
# 9   called to advise she is having some problems s...
# 11  cb  5204431666 user was having an issue with t...
# 13  when trying to access teams natasha gets promp...
# 12  user is having issues logging into to teams on...
# 10           i am unable to login keeper team link...
# 16  teams application installation required on use...
# 19  required ms teams  hostname  desktopet22m6n cb...
# 14         hi  my microsoft teams is not opening o...
# 18         hi  my teams application is not woking ...
# 15                           need to install ms teams
# 17  connected on teams and informed us that the co...
#
#                                    Description_digits  \
# 0   unable to log to sharepoint and teams cb 20840...
# 2   manish am getting below error while login into...
# 1                       she said password has expired
# 3   bsv it desk below users are not able to login ...
# 5                                                 nan
# 4   am receiving the below error message when try ...
# 6   dmodi hemendradeopa below user is not able to ...
# 7                           teams issue cb 8505541324
# 8                 team application issue cb5204431666
# 9   called to advise she is having some problems s...
# 11  cb 5204431666 user was having an issue with th...
# 13  when trying to access teams natasha gets promp...
# 12  user is having issues logging into to teams on...
# 10  i am unable to login keeper team link when i c...
# 16  teams application installation required on use...
# 19  required microsoft teams hostname desktopet22m...
# 14  hi my microsoft teams is not opening once the ...
# 18  hi my teams application is not woking am attac...
# 15                    need to install microsoft teams
# 17  connected on teams and informed us that the co...
#
#                                Description_re_concate __index_level_0__  \
# 0   unable to log to sharepoint and teams cb 20840...              2669
# 2   manish am getting below error while login into...              1974
# 1   she said password has expired unable to sign i...              3138
# 3   bsv it desk below users are not able to login ...               166
# 5                      nan not able to login in teams              4208
# 4   am receiving the below error message when try ...              2078
# 6   dmodi hemendradeopa below user is not able to ...               153
# 7               teams issue cb 8505541324 teams issue              2390
# 8   team application issue cb5204431666 teams appl...              1372
# 9   called to advise she is having some problems s...              2667
# 11  cb 5204431666 user was having an issue with th...              1371
# 13  when trying to access teams natasha gets promp...              1893
# 12  user is having issues logging into to teams on...              4699
# 10  i am unable to login keeper team link when i c...              1357
# 16  teams application installation required on use...              2448
# 19  required microsoft teams hostname desktopet22m...              2465
# 14  hi my microsoft teams is not opening once the ...              2900
# 18  hi my teams application is not woking am attac...              2002
# 15  need to install microsoft teams need to instal...               254
# 17  connected on teams and informed us that the co...              3636
#
#                                            embeddings     scores Cosine_Score  \
# 0   [-0.20379874110221863, -0.14271019399166107, -...  14.659274        0.791
# 2   [-0.21326568722724915, -0.2221154123544693, -0...  15.561868        0.781
# 1   [-0.06729351729154587, -0.20569178462028503, -...  15.462677        0.781
# 3   [0.27587559819221497, -0.7293131947517395, -0....  16.956728        0.773
# 5   [0.027764372527599335, -0.4279092252254486, -0...  17.633350        0.764
# 4   [-0.4583558440208435, -0.2991095185279846, -0....  17.276005        0.759
# 6   [0.12157537043094635, -0.4818180203437805, -0....  17.767136        0.759
# 7   [-0.2546917796134949, -0.4833206236362457, -0....  18.140224        0.758
# 8   [-0.1717270165681839, -0.5755763649940491, -0....  18.362724        0.753
# 9   [-0.05436166748404503, -0.3316386044025421, -0...  18.462669        0.742
# 11  [-0.10307715088129044, -0.44003966450691223, -...  19.224194        0.739
# 13  [0.03347156196832657, -0.48380547761917114, -0...  19.337900        0.738
# 12  [-0.006013932637870312, -0.31957897543907166, ...  19.325235        0.729
# 10  [0.027183499187231064, -0.19773709774017334, -...  19.041342        0.722
# 16  [-0.10646652430295944, -0.278309166431427, -0....  20.668745        0.713
# 19  [-0.2758072316646576, -0.22564859688282013, -0...  20.730021        0.707
# 14  [-0.4837971329689026, -0.26614946126937866, -0...  19.662521        0.706
# 18  [-0.32995185256004333, -0.5502090454101562, -0...  20.724447        0.705
# 15  [-0.3684003949165344, -0.22025944292545319, -0...  20.481485        0.696
# 17  [-0.44058072566986084, -0.22518429160118103, -...  20.693220        0.691
#
#         Cosine_Simlarity
# 0   [0.7909102335759153]
# 2   [0.7807703626189605]
# 1   [0.7809711789016316]
# 3   [0.7727711549809403]
# 5   [0.7644387541990159]
# 4   [0.7590956139123137]
# 6   [0.7585010099855292]
# 7   [0.7579982729556805]
# 8   [0.7526955425905203]
# 9   [0.7417923152956823]
# 11  [0.7393514317449792]
# 13  [0.7376641796754229]
# 12  [0.7285446118717659]
# 10  [0.7219389404107668]
# 16  [0.7131890836612664]
# 19  [0.7067972785213709]
# 14  [0.7056309463060462]
# 18  [0.7051951207543373]
# 15  [0.6960261260379447]
# 17  [0.6906610502923386]
#
# [20 rows x 28 columns]

# %%
from scipy.spatial.distance import cosine
cs = []
for i in samples_df['embeddings'] :
  distance = cosine(question_embedding, i)
  cs.append(np.round(1-distance, 3))

samples_df["Cosine_Score"] = cs
samples_df.sort_values("Cosine_Score", ascending=False, inplace=True)

# %%
for _, row in samples_df.iterrows():
    print(f"DESC: {row.Description_re_concate}")
    print(f"FAISS SCORE: {row.scores}")
    print(f"COSINE SCORE: {row.Cosine_Score}")
    print(f"Queue: {row.Queue}")
    print(f"CREATED DATE: {row.Created}")
    print(f"TICKET NUMBER: {row.Ticket_Number}")
    print("=" * 50)
    print()
# Out:
# DESC: unable to log to sharepoint and teams cb 2084098490 unable to log in to sharepoint and teams
# FAISS SCORE: 14.659274101257324
# COSINE SCORE: 0.791
# Queue: Global Shared Service Desk
# CREATED DATE: 8/22/2022 19:26
# TICKET NUMBER: T20220822.0393
# ==================================================
#
# DESC: manish am getting below error while login into teams on new laptop its asking for authenticator code kindly fix this issue and resolve teams error
# FAISS SCORE: 15.561867713928223
# COSINE SCORE: 0.781
# Queue: Merged Tickets
# CREATED DATE: 3/2/2022 18:26
# TICKET NUMBER: T20220302.0188
# ==================================================
#
# DESC: she said password has expired unable to sign in to teams
# FAISS SCORE: 15.462677001953125
# COSINE SCORE: 0.781
# Queue: Global Shared Service Desk
# CREATED DATE: 8/31/2022 20:40
# TICKET NUMBER: T20220831.0605
# ==================================================
#
# DESC: bsv it desk below users are not able to login on teams please have a look and fix the issue on priority please change the authentication method to text message for him email hemendradeopa phone no 7042611540 email mailto phone no 8447739983 not able to login on microsoft teams - #
# FAISS SCORE: 16.956727981567383
# COSINE SCORE: 0.773
# Queue: Global Shared Service Desk
# CREATED DATE: 1/25/2022 21:26
# TICKET NUMBER: T20220125.0391
# ==================================================
#
# DESC: nan not able to login in teams
# FAISS SCORE: 17.633350372314453
# COSINE SCORE: 0.764
# Queue: Global Shared Service Desk
# CREATED DATE: 3/26/2022 4:23
# TICKET NUMBER: T20220325.1419
# ==================================================
#
# DESC: am receiving the below error message when try to open teams am able to connect to all my other applications so do not believe it is network issue cid3590abb0811a4d348abc421236854954 can not access microsoft teams
# FAISS SCORE: 17.276004791259766
# COSINE SCORE: 0.759
# Queue: CDS-Northwest
# CREATED DATE: 3/3/2022 18:36
# TICKET NUMBER: T20220303.0229
# ==================================================
#
# DESC: dmodi hemendradeopa below user is not able to login on microsoft teams please have a look and fix the issue on priority please change the authentication method to text message for him email hemendradeopa phone no 7042611540 art ticket no 316915 not able to login on microsoft teams
# FAISS SCORE: 17.767135620117188
# COSINE SCORE: 0.759
# Queue: Global Shared Service Desk
# CREATED DATE: 1/24/2022 21:47
# TICKET NUMBER: T20220124.0470
# ==================================================
#
# DESC: teams issue cb 8505541324 teams issue
# FAISS SCORE: 18.14022445678711
# COSINE SCORE: 0.758
# Queue: Global Shared Service Desk
# CREATED DATE: 3/9/2022 1:08
# TICKET NUMBER: T20220308.1720
# ==================================================
#
# DESC: team application issue cb5204431666 teams application issue
# FAISS SCORE: 18.36272430419922
# COSINE SCORE: 0.753
# Queue: Global Shared Service Desk
# CREATED DATE: 4/22/2022 21:16
# TICKET NUMBER: T20220422.0611
# ==================================================
#
# DESC: called to advise she is having some problems signing into teams on the web teams issue
# FAISS SCORE: 18.462669372558594
# COSINE SCORE: 0.742
# Queue: Global Shared Service Desk
# CREATED DATE: 5/20/2022 19:39
# TICKET NUMBER: T20220520.0555
# ==================================================
#
# DESC: cb 5204431666 user was having an issue with the teams teams issue
# FAISS SCORE: 19.224193572998047
# COSINE SCORE: 0.739
# Queue: Global Shared Service Desk
# CREATED DATE: 4/22/2022 20:50
# TICKET NUMBER: T20220422.0566
# ==================================================
#
# DESC: when trying to access teams natasha gets prompt that something went wrong unable to access teams
# FAISS SCORE: 19.337900161743164
# COSINE SCORE: 0.738
# Queue: Business Development
# CREATED DATE: 8/5/2022 21:39
# TICKET NUMBER: T20220805.0677
# ==================================================
#
# DESC: user is having issues logging into to teams on mobile device acccess to microsoft teams on mobile device
# FAISS SCORE: 19.32523536682129
# COSINE SCORE: 0.729
# Queue: Global Shared Service Desk
# CREATED DATE: 6/27/2022 16:13
# TICKET NUMBER: T20220627.0187
# ==================================================
#
# DESC: i am unable to login keeper team link when i click on set up your account i am getting this error which is mentioned below unable to login in keeper team
# FAISS SCORE: 19.04134178161621
# COSINE SCORE: 0.722
# Queue: Merged Tickets
# CREATED DATE: 2/23/2022 19:07
# TICKET NUMBER: T20220223.0372
# ==================================================
#
# DESC: teams application installation required on user laptop call back 2523608306 teams application installation required on user laptop .
# FAISS SCORE: 20.668745040893555
# COSINE SCORE: 0.713
# Queue: Global Shared Service Desk
# CREATED DATE: 5/16/2022 20:30
# TICKET NUMBER: T20220516.0649
# ==================================================
#
# DESC: required microsoft teams hostname desktopet22m6n cb8059465804 required microsoft teams
# FAISS SCORE: 20.73002052307129
# COSINE SCORE: 0.707
# Queue: Global Shared Service Desk
# CREATED DATE: 5/17/2022 2:08
# TICKET NUMBER: T20220516.1576
# ==================================================
#
# DESC: hi my microsoft teams is not opening once the program itself is started microsoft teams not launching
# FAISS SCORE: 19.662521362304688
# COSINE SCORE: 0.706
# Queue: CDS-Northwest
# CREATED DATE: 3/14/2022 19:22
# TICKET NUMBER: T20220314.0560
# ==================================================
#
# DESC: hi my teams application is not woking am attaching screenshot for reference teams is not working
# FAISS SCORE: 20.72444725036621
# COSINE SCORE: 0.705
# Queue: Global Shared Service Desk
# CREATED DATE: 8/8/2022 15:19
# TICKET NUMBER: T20220808.0474
# ==================================================
#
# DESC: need to install microsoft teams need to install microsoft teams
# FAISS SCORE: 20.48148536682129
# COSINE SCORE: 0.696
# Queue: Global Shared Service Desk
# CREATED DATE: 4/5/2022 20:19
# TICKET NUMBER: T20220405.0599
# ==================================================
#
# DESC: connected on teams and informed us that the computer is not connecting with wifi connect wifi connection .
# FAISS SCORE: 20.693220138549805
# COSINE SCORE: 0.691
# Queue: Global Shared Service Desk
# CREATED DATE: 6/7/2022 10:47
# TICKET NUMBER: T20220606.1899
# ==================================================
